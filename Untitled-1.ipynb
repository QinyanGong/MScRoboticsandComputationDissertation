# %%
with open("demofile.txt", "w") as f:
    f.write("  Hello, it is 2024")
    f.write("\n   666")

# %%
with open("demofile.txt", "r") as f_in:
    with open("demofile_clean.txt", "w") as f_out:
        for s in f_in:
            s = s.strip()
            f_out.writelines(f"{s}\n")

# %%
with open("demofile_clean.txt", "r") as f_out:
    print(f_out.read())
# Out:
# Hello, it is 2024
# 666

# %% [markdown]
# # train and test loop
#
# \# for epoch in range
# for epoch in range(10):
#     # go model dot train
#     model.train()
#
#     # do the forward path
#     y_pred = model(x_train)
#
#     # calculate the loss
#     loss = loss_fn(y_pred, y_train)
#
#     # optimize the zerograd
#     optimizer.zero_grad()
#
#     # loss backward
#     loss.backward()
#
#     # optimizer step
#     optimizer.step()
#
#     # Let's test
#
#     # go model dot eval
#     model.eval()
#
#     # with inference mode
#     with torch.inference_mode():
#         # do the forward pass
#         test_pred = model(x_test)
#
#         # calculate the loss
#         test_loss = loss_fn(test_pred,y_test.type(torch.float))
#
#         # see what's happening
#         print(f"Epoch:{epoch} | MAE Train Loss {loss} | MAE Test Loss {test_loss}")

# %%
import torch
X = torch.rand(1,769,14,14)

# %%
X.flatten(2,3).shape
# Out:
# torch.Size([1, 769, 196])
